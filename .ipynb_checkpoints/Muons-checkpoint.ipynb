// %% [markdown]
// # Esperienza sui raggi cosmici
// In questa esperienza andremo a misurare il flusso di muoni a varie inclinazioni. Eseguiremo delle misuire di TOF

// %% [markdown]
// # Loogbook
//
// ## Long run 12-04-2022
// - start 12-04-2022 13:30
// - stop 13-04-2022 10:00
// - **Number of events** = 4953
// - **Number events written on disk** = 4953
//
//
// ## Distanze
//
// - Piano 0 a pavimento : 3.30 m
// - Piano 3 a pavimento : 0.35 m
// - Piano 3 a piano 2   : 0.06 m
// - Piano 3 a piano 1   : 0.24 m
// - Piano 3 a pinao 0   : 0.30 m
//
// Tabella dei dati
//
// |Da | A  | Misura |
// |---|----|--------|
// | 0 | Pav| 3.30   |
// | 3 | Pav| 0.35   |
// | 3 | 2  | 0.06   |
// | 3 | 1  | 0.24   |
// | 3 | 0  | 0.30   |
//
// ## Configurazione di misura del digitizer
//
// - CAEN NIM8305: dispositivo che raccoglie i segnali dai piani di scinitllatore, vengono settate delle soglie che permettono di generare un segnale TTL che consiste in un trigger. Il trigger viene quindi mandato a
// - Contatore di eventi
// - Digitizer per il campionamento della forma d'onda
//
// Il digitizer è un campionatore a 5 Gsps.
//
//
//
// ## Short run
//
// - durata 19' 47.88
// - **Number of events on display**  = 4351
// - **Number of events on disk** = 4350

// %%
TFile *_file0 = TFile::Open("LONG/wave_0.root");
tree->Print(); 

TCanvas* c1 = new TCanvas();
tree->Draw("vmax-vmin:Energy");
c1 -> Draw();
// Out:
// ******************************************************************************
// *Tree    :tree      : tree                                                   *
// *Entries :     4953 : Total =        41285214 bytes  File  Size =   21235320 *
// *        :          : Tree compression factor =   1.94                       *
// ******************************************************************************
// *Br    0 :header    : event/I:ncell/I                                        *
// *Entries :     4953 : Total  Size=      40338 bytes  File Size  =      17116 *
// *Baskets :        2 : Basket Size=      32000 bytes  Compression=   2.32     *
// *............................................................................*
// *Br    1 :reco      : vmin/D:vmax/D:vsmin/D:vsmax/D:Energy/D:Time/D:STime/D: *
// *         | tsmin/D:tsmax/D:p0/D:p1/D                                        *
// *Entries :     4953 : Total  Size=     438326 bytes  File Size  =     329813 *
// ...

// %%
TFile *_file0 = TFile::Open("LONG/wave_0_reco.root");
TCanvas* c1 = new TCanvas();
tree->Draw("vmax-vmin:Energy");
c1 -> Draw();
// Out:
// Warning in <TFile::Init>: file LONG/wave_0_reco.root probably not closed, trying to recover
// Warning in <TFile::Init>: no keys recovered, file has been made a Zombie

// %% [markdown]
// # Direction 1

// %%
double ipotenusa = 0.52;
double cateto = 0.447;

double cos_2 = pow(TMath::Cos(TMath::ASin(cateto/ipotenusa)),2);
cos_2

// %% [markdown]
// # Time calibration
// Measuring the delays in the signals between two plates in one configuration and then flipping them and repeating the measurement allows for the removal of the delay due to the cables.
//
// In the first configuration we find:
//
// $-4.97815e+01 \pm  1.59768e-02 = t_1-t_0$
//
// $-2.63188e+01 \pm  2.22969e-02 = t_2-t_0$
//
// $-2.68886e+01 \pm  2.45819e-02 = t_3-t_0$
//
// Flipping the detector:
//
// $-5.01835e+01 \pm  1.06227e-04 = t_1-t_0$
//
// $-2.81133e+01 \pm  1.36318e-04 = t_2-t_0$
//
// $-2.90723e+01 \pm  5.22752e-04 = t_3-t_0$
// ```
// __________FLIPPED____________-
// 1  Constant     1.35129e+02   2.66103e+00   9.56914e-03  -1.22292e-04
//    2  Mean        -5.01928e+01   1.63650e-02   7.32863e-05   1.05142e-02
//    3  Sigma        1.01754e+00   1.23809e-02   1.47134e-05  -2.68256e-02
//                                ERR DEF= 0.5
//  FCN=38.4697 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=4.30568e-11    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.93810e+02   3.73768e+00   1.31479e-02   1.12873e-06
//    2  Mean        -2.81118e+01   2.24294e-02   9.66861e-05   6.80698e-06
//    3  Sigma        1.42493e+00   1.58925e-02   1.30789e-05  -8.45929e-04
//                                ERR DEF= 0.5
//  FCN=47.5879 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=4.10648e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.71610e+02   3.33002e+00   1.29326e-02  -1.60032e-05
//    2  Mean        -2.90898e+01   2.55146e-02   1.22125e-04   1.82298e-03
//    3  Sigma        1.61109e+00   1.85112e-02   1.49174e-05  -5.72525e-03
// ```
//
// ```
// ______SHORT____________
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.68725e+02   3.16251e+00   1.19715e-02   2.97334e-05
//    2  Mean        -4.97773e+01   1.56589e-02   7.30760e-05   1.83043e-03
//    3  Sigma        1.02477e+00   1.13639e-02   1.40274e-05  -2.02741e-02
//                                ERR DEF= 0.5
//  FCN=41.2669 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=9.91449e-10    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.71094e+02   3.20091e+00   1.15939e-02   3.60555e-06
//    2  Mean        -2.63210e+01   2.20513e-02   9.83989e-05   9.38070e-04
//    3  Sigma        1.44604e+00   1.59431e-02   1.33408e-05  -4.02309e-03
//                                ERR DEF= 0.5
//  FCN=39.9177 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=2.46476e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.55224e+02   2.92233e+00   1.03559e-02   8.53508e-06
//    2  Mean        -2.68916e+01   2.44319e-02   1.07250e-04  -9.24989e-04
//    3  Sigma        1.59292e+00   1.80382e-02   1.34430e-05  -6.44532e-03
//                                ERR DEF= 0.5
//
// ```

// %% [markdown]
// # Computing $\beta$

// %%
//importing the data
TString fname="LONG/wave_0_reco.root";
TFile* F0 = TFile::Open(fname.Data());
//channel 0
TTree* ToF0 = (TTree*) F0->Get("tree");
ToF0->SetName("ToF0");
ToF0->SetTitle("ToF0");
//channel 1
fname.ReplaceAll("0_reco.root","1_reco.root");
TFile* F1 = TFile::Open(fname.Data());
TTree* ToF1 = (TTree*) F1->Get("tree");
ToF1->SetName("ToF1");
ToF1->SetTitle("ToF1");
//channel 2
fname.ReplaceAll("1_reco.root","2_reco.root");
TFile* F2 = TFile::Open(fname.Data());
TTree* ToF2 = (TTree*) F2->Get("tree");
ToF2->SetName("ToF2");
ToF2->SetTitle("ToF2");
//channel 3
fname.ReplaceAll("2_reco.root","3_reco.root");
TFile* F3 = TFile::Open(fname.Data());
TTree* ToF3 = (TTree*) F3->Get("tree");
ToF3->SetName("ToF3");
ToF3->SetTitle("ToF3");
//place everything in the same tree
ToF0->AddFriend(ToF1);
ToF0->AddFriend(ToF2);
ToF0->AddFriend(ToF3);

// %%
//remove delay given by cables
ToF0->SetAlias("T0","(ToF0.Time)");
ToF0->SetAlias("T1","(ToF1.Time-(-5.01928e+01-4.97773e+01)/2.)");
ToF0->SetAlias("T2","(ToF2.Time-(-2.81118e+01-2.63210e+01)/2.)");
ToF0->SetAlias("T3","(ToF3.Time-(-2.90898e+01-2.68916e+01)/2.)");

// %%
//time delays
TCanvas * c1 = new TCanvas();
c1->Divide(1,3);
c1->cd(1);
TH1D* h1 = new TH1D("h1","",70,5,17);
ToF0->Draw("T1-T0>>h1","","colz");
h1->Fit("gaus","L");
gPad->SetLogy();
c1->cd(2);
TH1D* h2 = new TH1D("h2","",70,5,17);
ToF0->Draw("T2-T0>>h2","","colz");
h2->Fit("gaus","L");
gPad->SetLogy();
c1->cd(3);
TH1D* h3 = new TH1D("h3","",70,5,17);
ToF0->Draw("T3-T0>>h3","","colz");
h3->Fit("gaus","L");
gPad->SetLogy();

c1->Draw()
// Out:
//  FCN=39.4765 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=2.39832e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.67854e+02   3.00446e+00   1.05398e-02  -1.90115e-04
//    2  Mean         1.03031e+01   2.89928e-02   1.26357e-04   5.14576e-03
//    3  Sigma        1.97831e+00   2.18404e-02   1.30140e-05  -6.88844e-02
//                                ERR DEF= 0.5
//  FCN=25.7732 FROM MIGRAD    STATUS=CONVERGED      58 CALLS          59 TOTAL
//                      EDM=4.31467e-09    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     1.70712e+02   3.03791e+00   8.66318e-03  -2.28765e-05
// ...

// %% [markdown]
// Notice that all 3 times are compatible within 2 sigmas.
// Also $\Delta_{02}$ is larger then $\Delta_{03}$ (within 2 sigmas).

// %%
TCanvas * c4 = new TCanvas();
ToF0->SetAlias("beta","(365/(T0-T3))/29.979");
ToF0->SetAlias("TRMS","(sqrt((T1*T1+T2*T2+T3*T3)/3.-(T1+T2+T3)*(T1+T2+T3)/9.))");
TH2D* h2b = new TH2D("h2b","",100,-2,2,100,-2,2);
ToF0->Draw("1./beta:log10(TRMS)>>h2b","","colz");
c4->Draw();

TCanvas * c5 = new TCanvas();
TH1D* h4 = new TH1D("h4","",100,-2,0);
ToF0->Draw("1./beta>>h4","abs(1/beta+1)<1");
h4->Fit("gaus","L");
c5->Draw();
// Out:
//  FCN=156.718 FROM MIGRAD    STATUS=CONVERGED      60 CALLS          61 TOTAL
//                      EDM=9.54561e-12    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  Constant     2.20997e+02   3.86364e+00   2.73136e-02   5.91694e-07
//    2  Mean        -8.51295e-01   2.52936e-03   2.19000e-05  -2.04727e-06
//    3  Sigma        1.77198e-01   1.78872e-03   2.37868e-05  -3.39413e-04
//                                ERR DEF= 0.5
// Warning in <TFile::Append>: Replacing existing TH1: h2b (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: h4 (Potential memory leak).
